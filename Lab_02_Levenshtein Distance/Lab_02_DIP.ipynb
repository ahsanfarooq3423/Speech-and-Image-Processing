# %%
import numpy as np

# %%
import numpy as np



#reference string
reference = 'this is some text and we would like to see if it has been identified correctly by speech recognition system'

#hypothesis string
hypothesis = 'this is a text and we would like to check what has been identified by the speech recognition'

#spliting the sentences into array of words
words_reference = reference.split()
words_hypothesis = hypothesis.split()
    
    
rows = len(words_reference) + 1
cols = len(words_hypothesis) + 1

#generating the martix of number of reference x number of hypothesis words
matrix = np.zeros((rows,cols),dtype = int)
    
same_distance = False
    
#Calculating the number of inserstions
no_of_insertions = 0
for word in s:
    if word not in words_hypothesis:
            no_of_insertions += 1
 



#Calculating the deleted number of words if they not present in reference text
no_of_deletions = 0
for word in t:
    if word not in words_reference:
        no_of_deletions +=1
    
    
# generarting words indices of both strings into matrix
for k in range(1,cols):
    matrix[i][0] = i
    matrix[0][k] = k
            

#Computing the number of substitions, deletions, and insertions
for col in range(1, cols):
    for row in range(1, rows):
        if s[row-1] == t[col-1]: 
            cost = 0 
        else:
            if same_distance == True:
                cost = 2
            else:
                cost = 1
        matrix[row][col] = min(matrix[row-1][col] + 1,      # Cost of deletions
                                 matrix[row][col-1] + 1,          # Cost of insertions
                                 matrix[row-1][col-1] + cost)

print('The Levenshtein Distance is :', str(distance[row][col]))
print("Number of Inserstions : ", str(no_of_insertions))
print("Number of Deletions: " , str(no_of_deletions))
# Out:
# The Levenshtein Distance is : 7
# Number of Inserstions :  6
# Number of Deletions:  4

# %%
import numpy as np
common_words = ['the','of','and','a','be','this','there','an','been','some']



#reference string
reference = 'this is some text and we would like to see if it has been identified correctly by speech recognition system'

#hypothesis string
hypothesis = 'this is a text and we would like to check what has been identified by the speech recognition'

#spliting the sentences into array of words
words_reference = reference.split()
words_hypothesis = hypothesis.split()
    
    
rows = len(words_reference) + 1
cols = len(words_hypothesis) + 1

#generating the martix of number of reference x number of hypothesis words
matrix = np.zeros((rows,cols),dtype = int)
    
same_distance = False
    
#Calculating the number of inserstions
no_of_insertions = 0
for word in s:
    if word in common_words:
            continue
    elif word not in words_hypothesis:
            no_of_insertions += 1
 



#Calculating the deleted number of words if they not present in reference text
no_of_deletions = 0
for word in t:
    if word in common_words:
        continue
    elif word not in words_reference:
        no_of_deletions +=1
    
    
# generarting words indices of both strings into matrix
for k in range(1,cols):
    matrix[i][0] = i
    matrix[0][k] = k
            

#Computing the number of substitions, deletions, and insertions
for col in range(1, cols):
    for row in range(1, rows):
        if s[row-1] == t[col-1] or words_reference[row-1] in common_words or words_hypothesis[col - 1] in common_words: 
            cost = 0 
        else:
            if same_distance == True:
                cost = 2
            else:
                cost = 1
        matrix[row][col] = min(matrix[row-1][col] + 1,      # Cost of deletions
                                 matrix[row][col-1] + 1,          # Cost of insertions
                                 matrix[row-1][col-1] + cost)

print('The Levenshtein Distance is :', str(distance[row][col]))
print("Number of Inserstions : ", str(no_of_insertions))
print("Number of Deletions: " , str(no_of_deletions))
# Out:
# The Levenshtein Distance is : 7
# Number of Inserstions :  5
# Number of Deletions:  2
